# %% [markdown]
# ## Parte 1
# Red con Keras

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import numpy as np

print ("Librerías listas, puede continuar.")
# Out:
# Librerías listas, puede continuar.

# %%
# Cargar el conjunto de datos MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
fig, axes = plt.subplots(nrows=10, ncols=9, figsize=(18, 18))

for digit in range(10):  # Del 0 al 8
    indices = np.where(train_labels == digit)[0][:9]  # Obtener tres índices de imágenes del mismo número
    for col, idx in enumerate(indices):
        axes[digit, col].imshow(train_images[idx], cmap='gray')
        axes[digit, col].axis('off')
        
plt.tight_layout()
plt.savefig("Datos_MNIST.png")
plt.show()

# %%
index = 5
image = train_images[index]
plt.imshow(image, cmap='gray')
plt.title('Dígito: {}'.format(train_labels[index]))
plt.savefig("Imagen_ejemplo_MNIST")
plt.show()

# %%
index = 10
image = train_images[index]
plt.imshow(image, cmap='gray')
plt.title('Dígito: {}'.format(train_labels[index]))
plt.savefig("Imagen_ejemplo_MNIST_2")
plt.show()

# %%
# Reestructuración los datos
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Creación del modelo [784, 30, 10]
model = models.Sequential()
model.add(layers.Dense(784, activation='sigmoid', input_shape=(28 * 28,)))
model.add(layers.Dense(30, activation='sigmoid', input_shape=(28 * 28,)))
model.add(layers.Dense(10, activation='softmax'))

# %%
# Compilar el modelo
custom_optimizer = RMSprop(learning_rate=0.001, rho=0.9, epsilon=1e-09)

model.compile(optimizer = custom_optimizer,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Entrenar el modelo
history = model.fit(train_images, train_labels, epochs=30, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/30
# 4800/4800 [==============================] - 22s 4ms/step - loss: 0.3658 - accuracy: 0.8999 - val_loss: 0.1831 - val_accuracy: 0.9463
# Epoch 2/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.1560 - accuracy: 0.9538 - val_loss: 0.1286 - val_accuracy: 0.9644
# Epoch 3/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.1088 - accuracy: 0.9679 - val_loss: 0.1111 - val_accuracy: 0.9695
# Epoch 4/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0855 - accuracy: 0.9754 - val_loss: 0.1062 - val_accuracy: 0.9716
# Epoch 5/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0691 - accuracy: 0.9805 - val_loss: 0.1052 - val_accuracy: 0.9716
# Epoch 6/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0560 - accuracy: 0.9840 - val_loss: 0.1110 - val_accuracy: 0.9722
# Epoch 7/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0491 - accuracy: 0.9867 - val_loss: 0.0976 - val_accuracy: 0.9766
# Epoch 8/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0415 - accuracy: 0.9884 - val_loss: 0.1011 - val_accuracy: 0.9753
# Epoch 9/30
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0363 - accuracy: 0.9904 - val_loss: 0.0967 - val_accuracy: 0.9787
# Epoch 10/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0302 - accuracy: 0.9915 - val_loss: 0.0989 - val_accuracy: 0.9781
# Epoch 11/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0266 - accuracy: 0.9932 - val_loss: 0.1095 - val_accuracy: 0.9769
# Epoch 12/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.1058 - val_accuracy: 0.9787
# Epoch 13/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.1094 - val_accuracy: 0.9786
# Epoch 14/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0170 - accuracy: 0.9956 - val_loss: 0.1214 - val_accuracy: 0.9747
# Epoch 15/30
# 4800/4800 [==============================] - 16s 3ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.1128 - val_accuracy: 0.9795
# Epoch 16/30
# 4800/4800 [==============================] - 16s 3ms/step - loss: 0.0135 - accuracy: 0.9969 - val_loss: 0.1096 - val_accuracy: 0.9799
# Epoch 17/30
# 4800/4800 [==============================] - 16s 3ms/step - loss: 0.0111 - accuracy: 0.9973 - val_loss: 0.1127 - val_accuracy: 0.9785
# Epoch 18/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0099 - accuracy: 0.9975 - val_loss: 0.1189 - val_accuracy: 0.9787
# Epoch 19/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.1316 - val_accuracy: 0.9780
# Epoch 20/30
# 4800/4800 [==============================] - 16s 3ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.1314 - val_accuracy: 0.9795
# Epoch 21/30
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.1194 - val_accuracy: 0.9806
# Epoch 22/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.1270 - val_accuracy: 0.9790
# Epoch 23/30
# 4800/4800 [==============================] - 24s 5ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1383 - val_accuracy: 0.9781
# Epoch 24/30
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.1392 - val_accuracy: 0.9782
# Epoch 25/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.1428 - val_accuracy: 0.9782
# Epoch 26/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.1400 - val_accuracy: 0.9787
# Epoch 27/30
# 4800/4800 [==============================] - 16s 3ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1315 - val_accuracy: 0.9805
# Epoch 28/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1389 - val_accuracy: 0.9798
# Epoch 29/30
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1429 - val_accuracy: 0.9792
# Epoch 30/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1470 - val_accuracy: 0.9777

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1202 - accuracy: 0.9819
# Precisión en el conjunto de prueba: 0.9818999767303467

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values)+1)
plt.plot(epoch,loss_values, 'o',label='training')
plt.plot(epoch,val_loss_values, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ¿Obtuviste resultados similares? No, fueron notablemente mejores. Se obtuvo un accurancy del 0.9815 contra un 0.8412 del anterior modelo utilizando CPU. Mientras que al cambiar el entorno a una T4 GPU el tiempo se redujo a 9 minutos y un accurancy de 0.9818. El sobreajuste se mantiene igual en cada caso.
#
#
# ¿Tardó lo mismo para entrenar el mismo número de epocas? Tardó menos, un aproximado de 21 minutos contra los casi 30 anteriormente.

# %% [markdown]
# ## Parte 2

# %% [markdown]
# ### Modificacion de parámetros 1

# %%
#import tensorflow as tf
#import matplotlib.pyplot as plt
#from tensorflow.keras import layers, models
#from tensorflow.keras.datasets import mnist
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Cargar el conjunto de datos MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
# Reestructuración los datos
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Creación del modelo
model2 = models.Sequential()
model2.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
model2.add(layers.Dense(30, activation='relu', input_shape=(28 * 28,)))
model2.add(layers.Dense(10, activation='softmax'))

# %%
# Compilar el modelo
custom_optimizer2 = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

model2.compile(optimizer = custom_optimizer2,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Entrenar el modelo
history2 = model2.fit(train_images, train_labels, epochs=50, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/50
# 4800/4800 [==============================] - 24s 5ms/step - loss: 0.3773 - accuracy: 0.8982 - val_loss: 0.1842 - val_accuracy: 0.9497
# Epoch 2/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.1574 - accuracy: 0.9556 - val_loss: 0.1350 - val_accuracy: 0.9621
# Epoch 3/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.1097 - accuracy: 0.9691 - val_loss: 0.1134 - val_accuracy: 0.9671
# Epoch 4/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0826 - accuracy: 0.9764 - val_loss: 0.1003 - val_accuracy: 0.9697
# Epoch 5/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0655 - accuracy: 0.9814 - val_loss: 0.0879 - val_accuracy: 0.9753
# Epoch 6/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0514 - accuracy: 0.9858 - val_loss: 0.0896 - val_accuracy: 0.9733
# Epoch 7/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0413 - accuracy: 0.9888 - val_loss: 0.0799 - val_accuracy: 0.9763
# Epoch 8/50
# 4800/4800 [==============================] - 21s 4ms/step - loss: 0.0329 - accuracy: 0.9909 - val_loss: 0.0814 - val_accuracy: 0.9768
# Epoch 9/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0262 - accuracy: 0.9931 - val_loss: 0.0815 - val_accuracy: 0.9763
# Epoch 10/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0212 - accuracy: 0.9946 - val_loss: 0.0857 - val_accuracy: 0.9756
# Epoch 11/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0171 - accuracy: 0.9959 - val_loss: 0.0799 - val_accuracy: 0.9795
# Epoch 12/50
# 4800/4800 [==============================] - 24s 5ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.0805 - val_accuracy: 0.9774
# Epoch 13/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0793 - val_accuracy: 0.9793
# Epoch 14/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.0860 - val_accuracy: 0.9788
# Epoch 15/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.0960 - val_accuracy: 0.9771
# Epoch 16/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.0821 - val_accuracy: 0.9805
# Epoch 17/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0855 - val_accuracy: 0.9790
# Epoch 18/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.0872 - val_accuracy: 0.9794
# Epoch 19/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0934 - val_accuracy: 0.9787
# Epoch 20/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1028 - val_accuracy: 0.9783
# Epoch 21/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0884 - val_accuracy: 0.9806
# Epoch 22/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0945 - val_accuracy: 0.9802
# Epoch 23/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0945 - val_accuracy: 0.9807
# Epoch 24/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0952 - val_accuracy: 0.9806
# Epoch 25/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1012 - val_accuracy: 0.9803
# Epoch 26/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1025 - val_accuracy: 0.9804
# Epoch 27/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 8.3067e-04 - accuracy: 0.9999 - val_loss: 0.1065 - val_accuracy: 0.9802
# Epoch 28/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 9.3600e-04 - accuracy: 0.9998 - val_loss: 0.1084 - val_accuracy: 0.9794
# Epoch 29/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1131 - val_accuracy: 0.9789
# Epoch 30/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 6.6072e-04 - accuracy: 0.9999 - val_loss: 0.1124 - val_accuracy: 0.9796
# Epoch 31/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 8.6761e-04 - accuracy: 0.9998 - val_loss: 0.1113 - val_accuracy: 0.9803
# Epoch 32/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 1.6720e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9798
# Epoch 33/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 8.6437e-04 - accuracy: 0.9997 - val_loss: 0.1119 - val_accuracy: 0.9814
# Epoch 34/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 8.9471e-04 - accuracy: 0.9998 - val_loss: 0.1161 - val_accuracy: 0.9804
# Epoch 35/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 1.9784e-04 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9802
# Epoch 36/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 7.7534e-04 - accuracy: 0.9998 - val_loss: 0.1181 - val_accuracy: 0.9814
# Epoch 37/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 4.9868e-04 - accuracy: 0.9998 - val_loss: 0.1194 - val_accuracy: 0.9803
# Epoch 38/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 2.5513e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9812
# Epoch 39/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 6.0993e-04 - accuracy: 0.9998 - val_loss: 0.1180 - val_accuracy: 0.9812
# Epoch 40/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 8.5740e-04 - accuracy: 0.9999 - val_loss: 0.1256 - val_accuracy: 0.9808
# Epoch 41/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 8.4345e-04 - accuracy: 0.9997 - val_loss: 0.1206 - val_accuracy: 0.9814
# Epoch 42/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 5.1726e-04 - accuracy: 0.9999 - val_loss: 0.1473 - val_accuracy: 0.9765
# Epoch 43/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 7.5003e-04 - accuracy: 0.9998 - val_loss: 0.1290 - val_accuracy: 0.9812
# Epoch 44/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 6.8802e-05 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9815
# Epoch 45/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 6.7236e-04 - accuracy: 0.9997 - val_loss: 0.1300 - val_accuracy: 0.9799
# Epoch 46/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 1.5033e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9815
# Epoch 47/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 5.5870e-04 - accuracy: 0.9998 - val_loss: 0.1312 - val_accuracy: 0.9801
# Epoch 48/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 4.9067e-05 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9818
# Epoch 49/50
# 4800/4800 [==============================] - 17s 3ms/step - loss: 9.3731e-04 - accuracy: 0.9998 - val_loss: 0.1402 - val_accuracy: 0.9815
# Epoch 50/50
# 4800/4800 [==============================] - 17s 4ms/step - loss: 9.1781e-04 - accuracy: 0.9998 - val_loss: 0.1530 - val_accuracy: 0.9772

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss2, test_acc2 = model2.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc2)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1383 - accuracy: 0.9798
# Precisión en el conjunto de prueba: 0.9797999858856201

# %%
history_dict2 = history2.history
loss_values2 = history_dict2['loss']
val_loss_values2 = history_dict2['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values2)+1)
plt.plot(epoch,loss_values2, 'o',label='training')
plt.plot(epoch,val_loss_values2, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# En esta red seleccioné un activación 'relu' para las capas ocultas y una softmax para la última capa. Aumenté el número de epocas por 50 y trabajé con una $\eta = 0.0001$ y Modifiqué el número de neuronas utilizadas de ([784,30,10]) por ([512,30,10]).
# Los resultados fueron un mayor sobreajuste y saltos en la convergencia final, por estar muy cerca del accurancy de 1.000.

# %% [markdown]
# ### Modificacion de parámetros 2

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Cargar el conjunto de datos MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Reestructuración los datos
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Creación del modelo
model3 = models.Sequential()
model3.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
#model3.add(layers.Dense(128, activation='relu', input_shape=(28 * 28,)))
model3.add(layers.Dense(24, activation='relu', input_shape=(28 * 28,)))
model3.add(layers.Dense(10, activation='softmax'))

# %%
# Compilar el modelo
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)

model3.compile(optimizer = custom_optimizer3,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Entrenar el modelo
history3 = model3.fit(train_images, train_labels, epochs=30, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/30
# 4800/4800 [==============================] - 23s 4ms/step - loss: 1.0514 - accuracy: 0.7498 - val_loss: 0.4790 - val_accuracy: 0.8932
# Epoch 2/30
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.4117 - accuracy: 0.8998 - val_loss: 0.3268 - val_accuracy: 0.9156
# Epoch 3/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.3162 - accuracy: 0.9174 - val_loss: 0.2750 - val_accuracy: 0.9259
# Epoch 4/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2719 - accuracy: 0.9280 - val_loss: 0.2450 - val_accuracy: 0.9342
# Epoch 5/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2429 - accuracy: 0.9347 - val_loss: 0.2239 - val_accuracy: 0.9381
# Epoch 6/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.2213 - accuracy: 0.9398 - val_loss: 0.2087 - val_accuracy: 0.9440
# Epoch 7/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.2040 - accuracy: 0.9447 - val_loss: 0.1952 - val_accuracy: 0.9476
# Epoch 8/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1895 - accuracy: 0.9482 - val_loss: 0.1840 - val_accuracy: 0.9505
# Epoch 9/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1770 - accuracy: 0.9516 - val_loss: 0.1764 - val_accuracy: 0.9513
# Epoch 10/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1663 - accuracy: 0.9550 - val_loss: 0.1673 - val_accuracy: 0.9545
# Epoch 11/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1564 - accuracy: 0.9574 - val_loss: 0.1608 - val_accuracy: 0.9554
# Epoch 12/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1476 - accuracy: 0.9598 - val_loss: 0.1542 - val_accuracy: 0.9577
# Epoch 13/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1398 - accuracy: 0.9625 - val_loss: 0.1484 - val_accuracy: 0.9590
# Epoch 14/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1328 - accuracy: 0.9639 - val_loss: 0.1433 - val_accuracy: 0.9608
# Epoch 15/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.1259 - accuracy: 0.9663 - val_loss: 0.1391 - val_accuracy: 0.9610
# Epoch 16/30
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.1199 - accuracy: 0.9678 - val_loss: 0.1362 - val_accuracy: 0.9622
# Epoch 17/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1143 - accuracy: 0.9696 - val_loss: 0.1304 - val_accuracy: 0.9634
# Epoch 18/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1089 - accuracy: 0.9713 - val_loss: 0.1270 - val_accuracy: 0.9645
# Epoch 19/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1039 - accuracy: 0.9727 - val_loss: 0.1240 - val_accuracy: 0.9647
# Epoch 20/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0993 - accuracy: 0.9740 - val_loss: 0.1213 - val_accuracy: 0.9657
# Epoch 21/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0950 - accuracy: 0.9749 - val_loss: 0.1182 - val_accuracy: 0.9662
# Epoch 22/30
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0909 - accuracy: 0.9765 - val_loss: 0.1149 - val_accuracy: 0.9677
# Epoch 23/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0873 - accuracy: 0.9777 - val_loss: 0.1121 - val_accuracy: 0.9690
# Epoch 24/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0835 - accuracy: 0.9785 - val_loss: 0.1100 - val_accuracy: 0.9689
# Epoch 25/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0800 - accuracy: 0.9796 - val_loss: 0.1079 - val_accuracy: 0.9698
# Epoch 26/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0769 - accuracy: 0.9804 - val_loss: 0.1061 - val_accuracy: 0.9703
# Epoch 27/30
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0738 - accuracy: 0.9813 - val_loss: 0.1046 - val_accuracy: 0.9700
# Epoch 28/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0708 - accuracy: 0.9825 - val_loss: 0.1030 - val_accuracy: 0.9706
# Epoch 29/30
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0679 - accuracy: 0.9827 - val_loss: 0.1023 - val_accuracy: 0.9710
# Epoch 30/30
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0654 - accuracy: 0.9836 - val_loss: 0.0996 - val_accuracy: 0.9713

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss3, test_acc3 = model3.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc3)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0943 - accuracy: 0.9722
# Precisión en el conjunto de prueba: 0.9721999764442444

# %%
history_dict3 = history3.history
loss_values3 = history_dict3['loss']
val_loss_values3 = history_dict3['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values3)+1)
plt.plot(epoch,loss_values3, 'o',label='training')
plt.plot(epoch,val_loss_values3, '--',label='val')


plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# En esta red seleccioné un activación 'relu' para las capas ocultas y una softmax para la última capa. Redujé el número de epocas a 30 y trabajé con una $\eta = 0.0001$ y Modifiqué el número de neuronas utilizadas de ([512,30,10]) por ([784,24,10]). También modifiqué los $\beta's$ para una aprendizaje más lento.
#
# Los resultados no mostraron sobreajuste, pero la tasa de aprendizaje fue más lenta y obtuvo un menor accurancy, 0.9721 respecto a un 0.9797 de la anterior configuración.

# %% [markdown]
# ### Tercera modificación

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Cargar el conjunto de datos MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Reestructuración los datos
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Creación del modelo
model4 = models.Sequential()
model4.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
#model3.add(layers.Dense(128, activation='relu', input_shape=(28 * 28,)))
model4.add(layers.Dense(24, activation='relu', input_shape=(28 * 28,)))
model4.add(layers.Dense(10, activation='softmax'))

# %%
# Compilar el modelo
custom_optimizer4 = Adam(learning_rate=0.000005, beta_1=0.97, beta_2=0.999, epsilon=1e-10)

model4.compile(optimizer = custom_optimizer4,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Entrenar el modelo
history4 = model4.fit(train_images, train_labels, epochs=50, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 1.3797 - accuracy: 0.6732 - val_loss: 0.8039 - val_accuracy: 0.8366
# Epoch 2/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.6556 - accuracy: 0.8543 - val_loss: 0.5068 - val_accuracy: 0.8842
# Epoch 3/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.4726 - accuracy: 0.8881 - val_loss: 0.4014 - val_accuracy: 0.9021
# Epoch 4/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.3921 - accuracy: 0.9021 - val_loss: 0.3459 - val_accuracy: 0.9134
# Epoch 5/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.3448 - accuracy: 0.9119 - val_loss: 0.3106 - val_accuracy: 0.9198
# Epoch 6/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.3122 - accuracy: 0.9183 - val_loss: 0.2857 - val_accuracy: 0.9237
# Epoch 7/50
# 4800/4800 [==============================] - 21s 4ms/step - loss: 0.2878 - accuracy: 0.9240 - val_loss: 0.2662 - val_accuracy: 0.9287
# Epoch 8/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.2683 - accuracy: 0.9288 - val_loss: 0.2517 - val_accuracy: 0.9310
# Epoch 9/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2520 - accuracy: 0.9325 - val_loss: 0.2377 - val_accuracy: 0.9357
# Epoch 10/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2382 - accuracy: 0.9359 - val_loss: 0.2267 - val_accuracy: 0.9390
# Epoch 11/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.2265 - accuracy: 0.9390 - val_loss: 0.2164 - val_accuracy: 0.9417
# Epoch 12/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2159 - accuracy: 0.9417 - val_loss: 0.2081 - val_accuracy: 0.9437
# Epoch 13/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.2066 - accuracy: 0.9438 - val_loss: 0.2003 - val_accuracy: 0.9454
# Epoch 14/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1980 - accuracy: 0.9458 - val_loss: 0.1938 - val_accuracy: 0.9479
# Epoch 15/50
# 4800/4800 [==============================] - 21s 4ms/step - loss: 0.1903 - accuracy: 0.9479 - val_loss: 0.1889 - val_accuracy: 0.9485
# Epoch 16/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1834 - accuracy: 0.9492 - val_loss: 0.1827 - val_accuracy: 0.9497
# Epoch 17/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1767 - accuracy: 0.9511 - val_loss: 0.1773 - val_accuracy: 0.9504
# Epoch 18/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1708 - accuracy: 0.9524 - val_loss: 0.1726 - val_accuracy: 0.9531
# Epoch 19/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1651 - accuracy: 0.9543 - val_loss: 0.1688 - val_accuracy: 0.9532
# Epoch 20/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1599 - accuracy: 0.9555 - val_loss: 0.1641 - val_accuracy: 0.9545
# Epoch 21/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.1550 - accuracy: 0.9566 - val_loss: 0.1605 - val_accuracy: 0.9558
# Epoch 22/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1503 - accuracy: 0.9584 - val_loss: 0.1561 - val_accuracy: 0.9571
# Epoch 23/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1461 - accuracy: 0.9593 - val_loss: 0.1536 - val_accuracy: 0.9563
# Epoch 24/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.1419 - accuracy: 0.9607 - val_loss: 0.1509 - val_accuracy: 0.9574
# Epoch 25/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1381 - accuracy: 0.9617 - val_loss: 0.1476 - val_accuracy: 0.9586
# Epoch 26/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1343 - accuracy: 0.9632 - val_loss: 0.1450 - val_accuracy: 0.9592
# Epoch 27/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.1308 - accuracy: 0.9639 - val_loss: 0.1420 - val_accuracy: 0.9593
# Epoch 28/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1274 - accuracy: 0.9648 - val_loss: 0.1397 - val_accuracy: 0.9608
# Epoch 29/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1243 - accuracy: 0.9657 - val_loss: 0.1385 - val_accuracy: 0.9605
# Epoch 30/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1213 - accuracy: 0.9666 - val_loss: 0.1352 - val_accuracy: 0.9609
# Epoch 31/50
# 4800/4800 [==============================] - 21s 4ms/step - loss: 0.1183 - accuracy: 0.9674 - val_loss: 0.1329 - val_accuracy: 0.9621
# Epoch 32/50
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.1154 - accuracy: 0.9685 - val_loss: 0.1314 - val_accuracy: 0.9620
# Epoch 33/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1128 - accuracy: 0.9692 - val_loss: 0.1293 - val_accuracy: 0.9634
# Epoch 34/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1101 - accuracy: 0.9702 - val_loss: 0.1274 - val_accuracy: 0.9638
# Epoch 35/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1075 - accuracy: 0.9711 - val_loss: 0.1264 - val_accuracy: 0.9638
# Epoch 36/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.1050 - accuracy: 0.9717 - val_loss: 0.1245 - val_accuracy: 0.9647
# Epoch 37/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1028 - accuracy: 0.9725 - val_loss: 0.1225 - val_accuracy: 0.9654
# Epoch 38/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.1005 - accuracy: 0.9729 - val_loss: 0.1208 - val_accuracy: 0.9651
# Epoch 39/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0984 - accuracy: 0.9737 - val_loss: 0.1192 - val_accuracy: 0.9662
# Epoch 40/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0962 - accuracy: 0.9744 - val_loss: 0.1184 - val_accuracy: 0.9667
# Epoch 41/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0941 - accuracy: 0.9748 - val_loss: 0.1165 - val_accuracy: 0.9676
# Epoch 42/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0921 - accuracy: 0.9756 - val_loss: 0.1160 - val_accuracy: 0.9667
# Epoch 43/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0902 - accuracy: 0.9756 - val_loss: 0.1156 - val_accuracy: 0.9677
# Epoch 44/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0884 - accuracy: 0.9763 - val_loss: 0.1132 - val_accuracy: 0.9684
# Epoch 45/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0865 - accuracy: 0.9772 - val_loss: 0.1119 - val_accuracy: 0.9681
# Epoch 46/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0848 - accuracy: 0.9773 - val_loss: 0.1109 - val_accuracy: 0.9688
# Epoch 47/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0831 - accuracy: 0.9780 - val_loss: 0.1096 - val_accuracy: 0.9693
# Epoch 48/50
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0814 - accuracy: 0.9785 - val_loss: 0.1091 - val_accuracy: 0.9685
# Epoch 49/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0798 - accuracy: 0.9790 - val_loss: 0.1080 - val_accuracy: 0.9696
# Epoch 50/50
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0782 - accuracy: 0.9792 - val_loss: 0.1066 - val_accuracy: 0.9699

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss4, test_acc4 = model4.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc4)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1016 - accuracy: 0.9698
# Precisión en el conjunto de prueba: 0.9697999954223633

# %%
history_dict4 = history4.history
loss_values4 = history_dict4['loss']
val_loss_values4 = history_dict4['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values4)+1)
plt.plot(epoch,loss_values4, 'o',label='training')
plt.plot(epoch,val_loss_values4, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Modificación del modelo 3. aumenté el número de epocas a 50 y trabajé con una $\eta = 0.00005$. También modifiqué los $\beta's$ para una aprendizaje más lento.
#
# Los resultados no mostraron sobreajuste, pero la tasa de aprendizaje fue más lenta y obtuvo un menor accurancy, 0.9697 respecto a un 0.9721 de la anterior configuración.

# %% [markdown]
# ### Guardado de modelos

# %%
# Guardar el primer modelo
model3.save("modelo3.h5")

# Guardar el segundo modelo con un nombre diferente
model4.save("modelo4.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Parte 3
# Implimentación de regularizadores

# %% [markdown]
# #### Entrenamiento hasta sobreajuste

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Cargar el conjunto de datos MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Reestructuración los datos
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Cargar el modelo preentrenado
modelo_preentrenado = tf.keras.models.load_model("modelo3.h5")

# Se define el callback ModelCheckpoint para guardar el mejor modelo en un archivo diferente
checkpoint_mejor_modelo = ModelCheckpoint("mejor_modelo_segundo_entrenamiento.h5", monitor="val_loss", save_best_only=True)

# Compilación del modelo preentrenado (utilizando el mismo optimizador y función de pérdida)
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)

modelo_preentrenado.compile(optimizer=custom_optimizer3, loss="categorical_crossentropy", metrics=["accuracy"])

# Entrena el modelo preentrenado con el callback para guardar el mejor modelo
history_train2 = modelo_preentrenado.fit(train_images, train_labels, epochs=60, batch_size=10,
                                         callbacks=[checkpoint_mejor_modelo],
                                         validation_split=0.2)

# Cargar el mejor modelo guardado durante el segundo entrenamiento
mejor_modelo_segundo_entrenamiento = tf.keras.models.load_model("mejor_modelo_segundo_entrenamiento.h5")
# Out:
# Epoch 1/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0630 - accuracy: 0.9844 - val_loss: 0.0973 - val_accuracy: 0.9718
# Epoch 2/60
#   27/4800 [..............................] - ETA: 19s - loss: 0.0693 - accuracy: 0.9815
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0603 - accuracy: 0.9849 - val_loss: 0.0967 - val_accuracy: 0.9719
# Epoch 3/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0581 - accuracy: 0.9856 - val_loss: 0.0947 - val_accuracy: 0.9729
# Epoch 4/60
# 4800/4800 [==============================] - 22s 4ms/step - loss: 0.0557 - accuracy: 0.9860 - val_loss: 0.0937 - val_accuracy: 0.9722
# Epoch 5/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0539 - accuracy: 0.9866 - val_loss: 0.0927 - val_accuracy: 0.9726
# Epoch 6/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0517 - accuracy: 0.9870 - val_loss: 0.0912 - val_accuracy: 0.9729
# Epoch 7/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0499 - accuracy: 0.9878 - val_loss: 0.0906 - val_accuracy: 0.9737
# Epoch 8/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0480 - accuracy: 0.9885 - val_loss: 0.0901 - val_accuracy: 0.9735
# Epoch 9/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0461 - accuracy: 0.9888 - val_loss: 0.0881 - val_accuracy: 0.9736
# Epoch 10/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0443 - accuracy: 0.9894 - val_loss: 0.0890 - val_accuracy: 0.9738
# Epoch 11/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0426 - accuracy: 0.9899 - val_loss: 0.0872 - val_accuracy: 0.9744
# Epoch 12/60
# 4800/4800 [==============================] - 22s 5ms/step - loss: 0.0411 - accuracy: 0.9902 - val_loss: 0.0861 - val_accuracy: 0.9752
# Epoch 13/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0397 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9747
# Epoch 14/60
# 4800/4800 [==============================] - 21s 4ms/step - loss: 0.0380 - accuracy: 0.9915 - val_loss: 0.0854 - val_accuracy: 0.9741
# Epoch 15/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0367 - accuracy: 0.9914 - val_loss: 0.0847 - val_accuracy: 0.9747
# Epoch 16/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0355 - accuracy: 0.9922 - val_loss: 0.0834 - val_accuracy: 0.9755
# Epoch 17/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0339 - accuracy: 0.9925 - val_loss: 0.0831 - val_accuracy: 0.9753
# Epoch 18/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0326 - accuracy: 0.9933 - val_loss: 0.0826 - val_accuracy: 0.9748
# Epoch 19/60
# 4800/4800 [==============================] - 22s 5ms/step - loss: 0.0316 - accuracy: 0.9935 - val_loss: 0.0835 - val_accuracy: 0.9749
# Epoch 20/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0303 - accuracy: 0.9936 - val_loss: 0.0816 - val_accuracy: 0.9755
# Epoch 21/60
# 4800/4800 [==============================] - 22s 5ms/step - loss: 0.0292 - accuracy: 0.9941 - val_loss: 0.0809 - val_accuracy: 0.9748
# Epoch 22/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0280 - accuracy: 0.9946 - val_loss: 0.0810 - val_accuracy: 0.9758
# Epoch 23/60
# 4800/4800 [==============================] - 22s 5ms/step - loss: 0.0270 - accuracy: 0.9949 - val_loss: 0.0803 - val_accuracy: 0.9755
# Epoch 24/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0260 - accuracy: 0.9950 - val_loss: 0.0805 - val_accuracy: 0.9758
# Epoch 25/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0249 - accuracy: 0.9952 - val_loss: 0.0804 - val_accuracy: 0.9764
# Epoch 26/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0240 - accuracy: 0.9956 - val_loss: 0.0794 - val_accuracy: 0.9758
# Epoch 27/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0230 - accuracy: 0.9959 - val_loss: 0.0797 - val_accuracy: 0.9761
# Epoch 28/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0222 - accuracy: 0.9961 - val_loss: 0.0795 - val_accuracy: 0.9764
# Epoch 29/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0213 - accuracy: 0.9963 - val_loss: 0.0799 - val_accuracy: 0.9756
# Epoch 30/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0204 - accuracy: 0.9966 - val_loss: 0.0788 - val_accuracy: 0.9763
# Epoch 31/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0196 - accuracy: 0.9967 - val_loss: 0.0791 - val_accuracy: 0.9768
# Epoch 32/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0188 - accuracy: 0.9970 - val_loss: 0.0785 - val_accuracy: 0.9762
# Epoch 33/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0180 - accuracy: 0.9973 - val_loss: 0.0782 - val_accuracy: 0.9765
# Epoch 34/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0172 - accuracy: 0.9971 - val_loss: 0.0788 - val_accuracy: 0.9761
# Epoch 35/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0166 - accuracy: 0.9976 - val_loss: 0.0790 - val_accuracy: 0.9762
# Epoch 36/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0159 - accuracy: 0.9976 - val_loss: 0.0775 - val_accuracy: 0.9767
# Epoch 37/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0152 - accuracy: 0.9978 - val_loss: 0.0779 - val_accuracy: 0.9774
# Epoch 38/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0145 - accuracy: 0.9979 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 39/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0140 - accuracy: 0.9980 - val_loss: 0.0775 - val_accuracy: 0.9773
# Epoch 40/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0134 - accuracy: 0.9980 - val_loss: 0.0786 - val_accuracy: 0.9764
# Epoch 41/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0128 - accuracy: 0.9983 - val_loss: 0.0778 - val_accuracy: 0.9771
# Epoch 42/60
# 4800/4800 [==============================] - 17s 3ms/step - loss: 0.0123 - accuracy: 0.9985 - val_loss: 0.0777 - val_accuracy: 0.9769
# Epoch 43/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0117 - accuracy: 0.9986 - val_loss: 0.0787 - val_accuracy: 0.9771
# Epoch 44/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0112 - accuracy: 0.9987 - val_loss: 0.0785 - val_accuracy: 0.9770
# Epoch 45/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0107 - accuracy: 0.9988 - val_loss: 0.0787 - val_accuracy: 0.9776
# Epoch 46/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0102 - accuracy: 0.9989 - val_loss: 0.0779 - val_accuracy: 0.9775
# Epoch 47/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.0779 - val_accuracy: 0.9777
# Epoch 48/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0093 - accuracy: 0.9991 - val_loss: 0.0778 - val_accuracy: 0.9774
# Epoch 49/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0089 - accuracy: 0.9993 - val_loss: 0.0787 - val_accuracy: 0.9782
# Epoch 50/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0085 - accuracy: 0.9992 - val_loss: 0.0789 - val_accuracy: 0.9778
# Epoch 51/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0081 - accuracy: 0.9993 - val_loss: 0.0796 - val_accuracy: 0.9776
# Epoch 52/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0077 - accuracy: 0.9994 - val_loss: 0.0785 - val_accuracy: 0.9774
# Epoch 53/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0073 - accuracy: 0.9994 - val_loss: 0.0803 - val_accuracy: 0.9781
# Epoch 54/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0070 - accuracy: 0.9995 - val_loss: 0.0801 - val_accuracy: 0.9780
# Epoch 55/60
# 4800/4800 [==============================] - 20s 4ms/step - loss: 0.0066 - accuracy: 0.9996 - val_loss: 0.0802 - val_accuracy: 0.9779
# Epoch 56/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0063 - accuracy: 0.9996 - val_loss: 0.0802 - val_accuracy: 0.9787
# Epoch 57/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0060 - accuracy: 0.9996 - val_loss: 0.0799 - val_accuracy: 0.9782
# Epoch 58/60
# 4800/4800 [==============================] - 19s 4ms/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.0795 - val_accuracy: 0.9787
# Epoch 59/60
# 4800/4800 [==============================] - 17s 4ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0795 - val_accuracy: 0.9786
# Epoch 60/60
# 4800/4800 [==============================] - 18s 4ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.0804 - val_accuracy: 0.9787

# %%
# Evaluación el modelo en el conjunto de prueba
test_lossR3, test_accR3 = mejor_modelo_segundo_entrenamiento.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_accR3)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0696 - accuracy: 0.9790
# Precisión en el conjunto de prueba: 0.9789999723434448

# %%
history_dictR3 = history_train2.history
loss_valuesR3 = history_dictR3['loss']
val_loss_valuesR3 = history_dictR3['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_valuesR3)+1)
plt.plot(epoch,loss_valuesR3, 'o',label='training')
plt.plot(epoch,val_loss_valuesR3, '--',label='val')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e42fb1ff7f82> in <cell line: 1>()
# ----> 1 history_dictR3 = history_train2.history
#       2 loss_valuesR3 = history_dictR3['loss']
#       3 val_loss_valuesR3 = history_dictR3['val_loss']
#       4
#       5 fig = plt.figure(figsize=(10,10))
#
# NameError: name 'history_train2' is not defined

# %% [markdown]
# #### L1

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Cargar el modelo preentrenado
modelo_preentrenado_l1 = tf.keras.models.load_model("mejor_modelo_segundo_entrenamiento.h5")

# Agregar capas de dropout y regularización L1
modelo_preentrenado_l1.add(layers.Dense(10, activation='relu', kernel_regularizer=l1(0.00001), name="mi_capa_l1"))

# Compilar el modelo con las nuevas configuraciones
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)
modelo_preentrenado_l1.compile(optimizer=custom_optimizer3, loss="categorical_crossentropy", metrics=["accuracy"])

# Define el callback ModelCheckpoint para guardar el mejor modelo
checkpoint_mejor_modelo_l1 = ModelCheckpoint("mejor_modelo_l1.h5", monitor="val_loss", save_best_only=True)

# Entrena el modelo preentrenado con el callback para guardar el mejor modelo
history_train_l1 = modelo_preentrenado_l1.fit(train_images, train_labels, epochs=15, batch_size=10,
                                         callbacks=[checkpoint_mejor_modelo_l1],
                                         validation_split=0.2)

# Cargar el mejor modelo guardado durante el segundo entrenamiento
mejor_modelo_l1 = tf.keras.models.load_model("mejor_modelo_l1.h5")
# Out:
# Epoch 1/15
# 4783/4800 [============================>.] - ETA: 0s - loss: 6.6032 - accuracy: 0.1827
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4800/4800 [==============================] - 23s 4ms/step - loss: 6.5968 - accuracy: 0.1831 - val_loss: 4.7692 - val_accuracy: 0.2360
# Epoch 2/15
# 4800/4800 [==============================] - 21s 4ms/step - loss: 4.0507 - accuracy: 0.3882 - val_loss: 3.1242 - val_accuracy: 0.4302
# Epoch 3/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: 2.8745 - accuracy: 0.4858 - val_loss: 2.8998 - val_accuracy: 0.5124
# Epoch 4/15
# 4800/4800 [==============================] - 21s 4ms/step - loss: 2.7147 - accuracy: 0.5239 - val_loss: 2.7919 - val_accuracy: 0.5163
# Epoch 5/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.5941 - accuracy: 0.5552 - val_loss: 2.6764 - val_accuracy: 0.5475
# Epoch 6/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.4860 - accuracy: 0.5514 - val_loss: 2.6077 - val_accuracy: 0.5460
# Epoch 7/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.2483 - val_loss: nan - val_accuracy: 0.0995
# Epoch 8/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 9/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 10/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 11/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 12/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 13/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 14/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 15/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss_l1, test_acc_l1 = mejor_modelo_l1.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc_l1)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.5517 - accuracy: 0.5516
# Precisión en el conjunto de prueba: 0.5515999794006348

# %%
history_dict_l1 = history_train_l1.history
loss_values_l1 = history_dict_l1['loss']
val_loss_values_l1 = history_dict_l1['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values_l1)+1)
plt.plot(epoch,loss_values_l1, 'o',label='training')
plt.plot(epoch,val_loss_values_l1, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# El modelo con la regularización L1 pierde muy rápido los valores de entrenamiento.

# %% [markdown]
# #### L2

# %%
# Cargar el modelo preentrenado
modelo_preentrenado_l2 = tf.keras.models.load_model("mejor_modelo_segundo_entrenamiento.h5")

# Agregar capas de dropout y regularización L2
modelo_preentrenado_l2.add(layers.Dense(10, activation='relu', kernel_regularizer=l2(0.00001), name="mi_capa_l2"))

# Compilar el modelo con las nuevas configuraciones
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)
modelo_preentrenado_l2.compile(optimizer=custom_optimizer3, loss="categorical_crossentropy", metrics=["accuracy"])

# Define el callback ModelCheckpoint para guardar el mejor modelo
checkpoint_mejor_modelo_l2 = ModelCheckpoint("mejor_modelo_l2.h5", monitor="val_loss", save_best_only=True)

# Entrena el modelo preentrenado con el callback para guardar el mejor modelo
history_train_l2 = modelo_preentrenado_l2.fit(train_images, train_labels, epochs=15, batch_size=10,
                                         callbacks=[checkpoint_mejor_modelo_l2],
                                         validation_split=0.2)

# Cargar el mejor modelo guardado durante el segundo entrenamiento
mejor_modelo_l2 = tf.keras.models.load_model("mejor_modelo_l2.h5")
# Out:
# Epoch 1/15
# 4792/4800 [============================>.] - ETA: 0s - loss: 8.0105 - accuracy: 0.1354
# Exception ignored in: <function _xla_gc_callback at 0x7dcc363136d0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 98, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 4800/4800 [==============================] - 72s 15ms/step - loss: 8.0081 - accuracy: 0.1355 - val_loss: 4.7607 - val_accuracy: 0.1807
# Epoch 2/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: 3.9984 - accuracy: 0.2134 - val_loss: 3.6960 - val_accuracy: 0.2542
# Epoch 3/15
# 4800/4800 [==============================] - 21s 4ms/step - loss: 3.5573 - accuracy: 0.2635 - val_loss: 3.4585 - val_accuracy: 0.2905
# Epoch 4/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 3.3512 - accuracy: 0.3453 - val_loss: 3.3530 - val_accuracy: 0.4037
# Epoch 5/15
# 4800/4800 [==============================] - 22s 5ms/step - loss: 3.2269 - accuracy: 0.4128 - val_loss: 3.2322 - val_accuracy: 0.4177
# Epoch 6/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 3.0984 - accuracy: 0.4205 - val_loss: 3.1272 - val_accuracy: 0.4177
# Epoch 7/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.9865 - accuracy: 0.4279 - val_loss: 3.0413 - val_accuracy: 0.4187
# Epoch 8/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.9132 - accuracy: 0.4340 - val_loss: 2.9877 - val_accuracy: 0.4272
# Epoch 9/15
# 4800/4800 [==============================] - 23s 5ms/step - loss: 2.8234 - accuracy: 0.4443 - val_loss: 2.9134 - val_accuracy: 0.4363
# Epoch 10/15
# 4800/4800 [==============================] - 19s 4ms/step - loss: 2.7398 - accuracy: 0.4506 - val_loss: 2.8534 - val_accuracy: 0.4443
# Epoch 11/15
# 4800/4800 [==============================] - 23s 5ms/step - loss: 2.6657 - accuracy: 0.4580 - val_loss: 2.8390 - val_accuracy: 0.4458
# Epoch 12/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.6254 - accuracy: 0.4625 - val_loss: 2.7655 - val_accuracy: 0.4543
# Epoch 13/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.1581 - val_loss: nan - val_accuracy: 0.0995
# Epoch 14/15
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 15/15
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss_l2, test_acc_l2 = mejor_modelo_l2.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc_l2)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.6965 - accuracy: 0.4569
# Precisión en el conjunto de prueba: 0.4569000005722046

# %%
history_dict_l2 = history_train_l2.history
loss_values_l2 = history_dict_l2['loss']
val_loss_values_l2 = history_dict_l2['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values_l2)+1)
plt.plot(epoch,loss_values_l2, 'o',label='training')
plt.plot(epoch,val_loss_values_l2, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### L1-L2

# %%
# Cargar el modelo preentrenado
modelo_preentrenado_l1_l2 = tf.keras.models.load_model("mejor_modelo_segundo_entrenamiento.h5")

# Agregar capas de dropout y regularización L2
modelo_preentrenado_l1_l2.add(layers.Dense(10, activation='relu',
                                        kernel_regularizer=l1_l2(l1=0.00001, l2=0.0001),
                                        name="mi_capa_l1_l2"))

# Compilar el modelo con las nuevas configuraciones
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)
modelo_preentrenado_l1_l2.compile(optimizer=custom_optimizer3,
                                  loss="categorical_crossentropy",
                                  metrics=["accuracy"])

# Define el callback ModelCheckpoint para guardar el mejor modelo
checkpoint_mejor_modelo_l1_l2 = ModelCheckpoint("mejor_modelo_l1_l2.h5", monitor="val_loss", save_best_only=True)

# Entrena el modelo preentrenado con el callback para guardar el mejor modelo
history_train_l1_l2 = modelo_preentrenado_l1_l2.fit(train_images, train_labels, epochs=20, batch_size=10,
                                         callbacks=[checkpoint_mejor_modelo_l1_l2],
                                         validation_split=0.2)

# Cargar el mejor modelo guardado durante el segundo entrenamiento
mejor_modelo_l1_l2 = tf.keras.models.load_model("mejor_modelo_l1_l2.h5")
# Out:
# Epoch 1/20
# 4800/4800 [==============================] - 23s 4ms/step - loss: 8.8039 - accuracy: 0.3386 - val_loss: 8.4609 - val_accuracy: 0.3688
# Epoch 2/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 6.2218 - accuracy: 0.3679 - val_loss: 4.6940 - val_accuracy: 0.3777
# Epoch 3/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 4.4351 - accuracy: 0.3855 - val_loss: 4.2503 - val_accuracy: 0.3781
# Epoch 4/20
# 4800/4800 [==============================] - 21s 4ms/step - loss: 4.0030 - accuracy: 0.3737 - val_loss: 3.8205 - val_accuracy: 0.3647
# Epoch 5/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 3.6427 - accuracy: 0.3595 - val_loss: 3.4364 - val_accuracy: 0.3352
# Epoch 6/20
# 4800/4800 [==============================] - 22s 5ms/step - loss: 3.2242 - accuracy: 0.3560 - val_loss: 3.0304 - val_accuracy: 0.3960
# Epoch 7/20
# 4800/4800 [==============================] - 23s 5ms/step - loss: 2.8841 - accuracy: 0.4067 - val_loss: 2.7326 - val_accuracy: 0.4152
# Epoch 8/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.7037 - accuracy: 0.4875 - val_loss: 2.6247 - val_accuracy: 0.5197
# Epoch 9/20
# 4800/4800 [==============================] - 23s 5ms/step - loss: 2.6047 - accuracy: 0.5415 - val_loss: 2.5444 - val_accuracy: 0.5594
# Epoch 10/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.5243 - accuracy: 0.5813 - val_loss: 2.5006 - val_accuracy: 0.6337
# Epoch 11/20
# 4800/4800 [==============================] - 21s 4ms/step - loss: 2.4657 - accuracy: 0.6447 - val_loss: 2.4314 - val_accuracy: 0.6617
# Epoch 12/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: 2.3921 - accuracy: 0.6749 - val_loss: 2.3850 - val_accuracy: 0.6873
# Epoch 13/20
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.2982 - val_loss: nan - val_accuracy: 0.0995
# Epoch 14/20
# 4800/4800 [==============================] - 19s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 15/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 16/20
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 17/20
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 18/20
# 4800/4800 [==============================] - 23s 5ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 19/20
# 4800/4800 [==============================] - 26s 5ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 20/20
# 4800/4800 [==============================] - 25s 5ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss_l1_l2, test_acc_l1_l2 = mejor_modelo_l1_l2.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc_l1_l2)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3866 - accuracy: 0.6866
# Precisión en el conjunto de prueba: 0.6866000294685364

# %%
history_dict_l1_l2 = history_train_l1_l2.history
loss_values_l1_l2 = history_dict_l1_l2['loss']
val_loss_values_l1_l2 = history_dict_l1_l2['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values_l1_l2)+1)
plt.plot(epoch,loss_values_l1_l2, 'o',label='training')
plt.plot(epoch,val_loss_values_l1_l2, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Con la combinación de los reguladores L1-L2 se ha logrado llegar a un mejor acurrancy sin sobreajuste, sin embargo sigue siendo bajo con el detalle adicional que en pocas épocas se pierden los valores.

# %% [markdown]
# #### Dropout y L1-L2

# %%
# Cargar el modelo preentrenado
modelo_preentrenado_Dropout = tf.keras.models.load_model("mejor_modelo_segundo_entrenamiento.h5")

# Agregar capas de dropout y regularización L2
modelo_preentrenado_Dropout.add(layers.Dense(10, activation='relu',
                                        kernel_regularizer=l1_l2(l1=0.00001, l2=0.0001),
                                        name="mi_capa_Dropout"))
modelo_preentrenado_Dropout.add(Dropout(0.2))
modelo_preentrenado_Dropout.add(layers.Dense(10, activation='relu',
                                        kernel_regularizer=l1_l2(l1=0.00001, l2=0.0001),
                                        name="mi_capa_Dropout2"))

# Compilar el modelo con las nuevas configuraciones
custom_optimizer3 = Adam(learning_rate=0.00001, beta_1=0.95, beta_2=0.999, epsilon=1e-10)
modelo_preentrenado_Dropout.compile(optimizer=custom_optimizer3,
                                  loss="categorical_crossentropy",
                                  metrics=["accuracy"])

# Define el callback ModelCheckpoint para guardar el mejor modelo
checkpoint_mejor_modelo_Dropout = ModelCheckpoint("mejor_modelo_Dropout.h5",
                                                  monitor="val_loss", save_best_only=True)

# Entrena el modelo preentrenado con el callback para guardar el mejor modelo
history_train_Dropout = modelo_preentrenado_Dropout.fit(train_images, train_labels, epochs=25, batch_size=10,
                                         callbacks=[checkpoint_mejor_modelo_Dropout],
                                         validation_split=0.2)

# Cargar el mejor modelo guardado durante el segundo entrenamiento
mejor_modelo_Dropout = tf.keras.models.load_model("mejor_modelo_Dropout.h5")
# Out:
# Epoch 1/25
# 4800/4800 [==============================] - 23s 4ms/step - loss: 4.9259 - accuracy: 0.1947 - val_loss: 3.4786 - val_accuracy: 0.2525
# Epoch 2/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 3.7363 - accuracy: 0.2733 - val_loss: 2.9475 - val_accuracy: 0.3738
# Epoch 3/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: 3.0498 - accuracy: 0.3313 - val_loss: 2.0936 - val_accuracy: 0.4700
# Epoch 4/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 2.6583 - accuracy: 0.3723 - val_loss: 1.8816 - val_accuracy: 0.4725
# Epoch 5/25
# 4800/4800 [==============================] - 23s 5ms/step - loss: 2.3709 - accuracy: 0.3943 - val_loss: 1.5796 - val_accuracy: 0.4788
# Epoch 6/25
# 4800/4800 [==============================] - 22s 5ms/step - loss: 2.1080 - accuracy: 0.4214 - val_loss: 1.3342 - val_accuracy: 0.4871
# Epoch 7/25
# 4800/4800 [==============================] - 22s 5ms/step - loss: 1.9043 - accuracy: 0.4649 - val_loss: 1.2090 - val_accuracy: 0.5061
# Epoch 8/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 1.7332 - accuracy: 0.5364 - val_loss: 1.0900 - val_accuracy: 0.7362
# Epoch 9/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 1.5685 - accuracy: 0.6023 - val_loss: 0.9590 - val_accuracy: 0.7638
# Epoch 10/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: 1.4240 - accuracy: 0.6373 - val_loss: 0.9170 - val_accuracy: 0.7717
# Epoch 11/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 1.3184 - accuracy: 0.6552 - val_loss: 0.8426 - val_accuracy: 0.7756
# Epoch 12/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: 1.1317 - accuracy: 0.6716 - val_loss: nan - val_accuracy: 0.7830
# Epoch 13/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: 1.0772 - accuracy: 0.6806 - val_loss: nan - val_accuracy: 0.7903
# Epoch 14/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.6517 - val_loss: nan - val_accuracy: 0.0995
# Epoch 15/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 16/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 17/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 18/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 19/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 20/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 21/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 22/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 23/25
# 4800/4800 [==============================] - 20s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 24/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 25/25
# 4800/4800 [==============================] - 21s 4ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995

# %%
# Evaluación el modelo en el conjunto de prueba
test_loss_Dropout, test_acc_Dropout = mejor_modelo_Dropout.evaluate(test_images, test_labels)
print('Precisión en el conjunto de prueba:', test_acc_Dropout)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8788 - accuracy: 0.7722
# Precisión en el conjunto de prueba: 0.7721999883651733

# %%
history_dict_Dropout = history_train_Dropout.history
loss_values_Dropout = history_dict_Dropout['loss']
val_loss_values_Dropout = history_dict_Dropout['val_loss']

fig = plt.figure(figsize=(10,10))
epoch = range(1,len(loss_values_Dropout)+1)
plt.plot(epoch,loss_values_Dropout, 'o',label='training')
plt.plot(epoch,val_loss_values_Dropout, '--',label='val')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# La implementación de Dropout logró ralentizar el momento donde los valores se pierden, gracias a eso se logró llegar a un mejor accurancy de los resultados además de no caer en un sobreajuste. Accurancy: 0.77

# %%
# !git status
# !git add .
# !git commit -m "Implementación Dropout. Mejor accurancy pero aún se pierden los datos en pocas épocas"
# !git push

# %% [markdown]
# # Reporte de resultados

# %% [markdown]
# Logré obtener mejores resultados con un rango de aprendizaje lento y muchas epocas que volviendo a entrenar una red e implementando algún regularizador ya que los valores se perdían algo rápido con los regularizadores.
#
# La implementación de Dropout junto con los regularizadores logró obtener mejores resultados que todo el uso único de regularizadores, sin embargo aun se encontraron problemas de pérdida de información.
